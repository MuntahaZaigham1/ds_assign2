# %% [markdown]
# <a href="https://colab.research.google.com/github/MuntahaZaigham1/ds_assign2/blob/master/poly_normal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import plotly

# %%
data = np.loadtxt('/content/polynomialRegressionData.csv', delimiter=',')
No_of_cols = data.shape[1]
#X_train = data[:,(0,1)] #the feature_set
X_train = data[:,[0,1]] #feature set

print(X_train)
#X_train2 = data[:,1] 
Y_train=data[:,2]#the labels
n=2
x_array = np.ones((X_train.shape[0], n+1),dtype=np.float64)
for i in range(0,X_train.shape[0]):
    for j in range(0,n+1):
        x_array[i][j] = pow(X_train[i],j)
    theta = np.matmul(np.matmul(inv(np.matmul(x_array.transpose(), x_array)), x_array.transpose()), y_train)
# Out:
# [[ 23. 100.]
#  [ 16. 100.]
#  [  3.  88.]
#  [ 19. 100.]
#  [  6.  90.]
#  [  3.  88.]
#  [  3.  94.]
#  [  3.  90.]
#  [  4. 100.]
#  [  3. 100.]
#  [  5.   0.]
#  [  0.  59.]
#  [  4.   0.]
#  [  0.  75.]
#  [  0.   0.]
#  [ 23.  96.]
#  [ 20.  92.]
#  [  0.  28.]
#  [  0.  94.]
#  [  0.  80.]
#  [  2.  25.]
#  [  0. 100.]
#  [  0. 100.]
#  [  0.  58.]
#  [ 14.  77.]
#  [  8.  76.]
#  [  7.  55.]
#  [ 22. 100.]
#  [  5.  94.]
#  [  0.  85.]
#  [  0.   0.]
#  [  4.  90.]
#  [  4.  90.]
#  [  0.   0.]
#  [  0. 100.]
#  [  0.   0.]
#  [  0. 100.]
#  [  0.  50.]
#  [  0. 100.]
#  [  4.  81.]
#  [  0.  67.]
#  [  2.  97.]
#  [  0.  38.]
#  [  7.  82.]
#  [  0.   0.]
#  [  1.   0.]
#  [  0.   0.]
#  [  4.   0.]
#  [  9.  73.]
#  [  0.  89.]
#  [  0. 100.]
#  [  8.  75.]
#  [101.  96.]
#  [  0.  96.]
#  [  0.  46.]
#  [  0. 100.]
#  [  0.  78.]
#  [  0.   0.]
#  [  0.   0.]
#  [  0.  87.]
#  [  0.  96.]
#  [  0.  83.]
#  [  2.  91.]
#  [  5.  93.]
#  [  6.  93.]
#  [  8.  81.]
#  [  9.  80.]
#  [  0.  95.]
#  [ 45.  94.]
#  [ 45.  86.]
#  [ 40.  85.]
#  [  0. 100.]
#  [  3. 100.]
#  [  5. 100.]
#  [  0.   0.]
#  [  7.  97.]
#  [  0.  95.]
#  [ 12.  86.]
#  [ 42.  95.]
#  [ 24.  83.]
#  [ 17.  80.]
#  [  8.  87.]
#  [  4.   0.]
#  [  6.   0.]
#  [  3.  93.]
#  [ 17.   0.]
#  [  9.   0.]
#  [  0.  62.]
#  [  0.  75.]
#  [ 32.  94.]
#  [ 20.  93.]
#  [ 14.  90.]
#  [  3.  74.]
#  [  2.  83.]
#  [  0.  84.]
#  [  6.   0.]
#  [ 19.  68.]
#  [ 13.   0.]
#  [  0.  75.]
#  [  0.   0.]
#  [  0.   0.]
#  [  0. 100.]
#  [  6.  90.]
#  [  0.  72.]
#  [  2.  84.]
#  [  0.  67.]
#  [  1.  80.]
#  [  0.  88.]
#  [  0.  86.]
#  [  0. 100.]
#  [  0. 100.]
#  [  0.  86.]
#  [  0.  75.]
#  [  0.  88.]
#  [  0.  77.]
#  [  1.   0.]
#  [  0.   0.]
#  [  0. 100.]
#  [  0. 100.]
#  [ 26.  96.]
#  [  4.  78.]
#  [  0.  73.]
#  [  0. 100.]
#  [  6.   0.]
#  [  0. 100.]
#  [ 11.  78.]
#  [ 11.  82.]
#  [  3.  83.]
#  [  0. 100.]
#  [ 13.  72.]
#  [  0.  22.]
#  [  0.  50.]
#  [  0. 100.]
#  [  0. 100.]
#  [  0. 100.]
#  [  0.  70.]
#  [  0. 100.]
#  [  0.   0.]
#  [  0.   0.]
#  [  0. 100.]
#  [  0.   0.]
#  [  0. 100.]
#  [  0.   0.]
#  [  0.  98.]
#  [  0. 100.]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: only size-1 arrays can be converted to Python scalars
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-5d5a32d09294> in <module>()
#      11 for i in range(0,X_train.shape[0]):
#      12     for j in range(0,n+1):
# ---> 13         x_array[i][j] = pow(X_train[i],j)
#      14     theta = np.matmul(np.matmul(inv(np.matmul(x_array.transpose(), x_array)), x_array.transpose()), y_train)
#
# ValueError: setting an array element with a sequence.
